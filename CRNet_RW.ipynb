# %% [markdown]
# <a href="https://colab.research.google.com/github/ZeinabRahbar/Cayleynets-Graph-convolutional-neural-networks-with-complex-rational-spectral-filters-/blob/main/CRNet_RW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/toil2sweet/CRNet/
# Out:
# Cloning into 'CRNet'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 50 (delta 9), reused 27 (delta 4), pack-reused 11
# Receiving objects: 100% (50/50), 72.91 MiB | 29.58 MiB/s, done.
# Resolving deltas: 100% (11/11), done.

# %%
# %cd CRNet
# !python /content/CRNet/CRNet_I_MR.py
# Out:
# [Errno 2] No such file or directory: 'CRNet'
# /content/CRNet
# -------------------CRNet—I---------------------------
# Command: train on current task and then test on seen ones
# ######## random task order of current run: [1 3 2 4 5]
# Training accuracy on task 1 is 99.0250 %
# Test accuracy on task_1 is 98.2000%
# Training accuracy on task 2 is 99.6250 %
# Test accuracy on task_1 is 95.0500%
# Test accuracy on task_3 is 99.5500%
# Training accuracy on task 3 is 95.8583 %
# Test accuracy on task_1 is 87.8500%
# Test accuracy on task_3 is 98.2000%
# Test accuracy on task_2 is 94.4500%
# Training accuracy on task 4 is 97.5750 %
# Test accuracy on task_1 is 92.9000%
# Test accuracy on task_3 is 97.6500%
# Test accuracy on task_2 is 90.9500%
# Test accuracy on task_4 is 98.8000%
# Training accuracy on task 5 is 98.1167 %
# Test accuracy on task_1 is 93.6000%
# Test accuracy on task_3 is 97.0000%
# Test accuracy on task_2 is 88.4500%
# Test accuracy on task_4 is 97.9000%
# ...
